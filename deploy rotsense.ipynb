# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...

# %%
# %cd yolov5
# Out:
# D:\deep learning\rotsense\yolov5\yolov5

# %%
# !pip install -r requirements.txt
# !pip install opencv-python
# Out:
# Requirement already satisfied: gitpython>=3.1.30 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 7)) (1.24.4)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 8)) (4.11.0.86)
# Requirement already satisfied: pillow>=10.3.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 9)) (11.2.1)
# Requirement already satisfied: psutil in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 10)) (5.9.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 13)) (1.9.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 15)) (2.7.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 16)) (0.22.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 17)) (4.67.1)
# Requirement already satisfied: ultralytics>=8.2.64 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 18)) (8.3.159)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 27)) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: setuptools>=70.0.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from -r requirements.txt (line 42)) (78.1.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\anora\downloads\anaconda\lib\site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\anora\downloads\anaconda\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anora\downloads\anaconda\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\anora\downloads\anaconda\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anora\downloads\anaconda\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anora\downloads\anaconda\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anora\downloads\anaconda\lib\site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anora\downloads\anaconda\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anora\downloads\anaconda\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anora\downloads\anaconda\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anora\downloads\anaconda\lib\site-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2025.4.26)
# Requirement already satisfied: filelock in c:\users\anora\downloads\anaconda\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\anora\downloads\anaconda\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.13.3)
# Requirement already satisfied: networkx in c:\users\anora\downloads\anaconda\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\anora\downloads\anaconda\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\anora\downloads\anaconda\lib\site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2025.3.2)
# Requirement already satisfied: colorama in c:\users\anora\downloads\anaconda\lib\site-packages (from tqdm>=4.66.3->-r requirements.txt (line 17)) (0.4.6)
# Requirement already satisfied: py-cpuinfo in c:\users\anora\downloads\anaconda\lib\site-packages (from ultralytics>=8.2.64->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from ultralytics>=8.2.64->-r requirements.txt (line 18)) (2.0.14)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anora\downloads\anaconda\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anora\downloads\anaconda\lib\site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\anora\downloads\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (3.0.2)
# Requirement already satisfied: opencv-python in c:\users\anora\downloads\anaconda\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\anora\downloads\anaconda\lib\site-packages (from opencv-python) (1.24.4)

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in c:\users\anora\downloads\anaconda\lib\site-packages (2.7.1)
# Requirement already satisfied: torchvision in c:\users\anora\downloads\anaconda\lib\site-packages (0.22.1)
# Requirement already satisfied: filelock in c:\users\anora\downloads\anaconda\lib\site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\anora\downloads\anaconda\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in c:\users\anora\downloads\anaconda\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\anora\downloads\anaconda\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\anora\downloads\anaconda\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: numpy in c:\users\anora\downloads\anaconda\lib\site-packages (from torchvision) (1.24.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from torchvision) (11.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anora\downloads\anaconda\lib\site-packages (from jinja2->torch) (3.0.2)

# %%
# %cd "D:/deep learning/rotsense/yolov5"
# Out:
# D:\deep learning\rotsense\yolov5

# %%
import torch
import cv2

# Load trained YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'custom', path='best.pt', force_reload=True)

# Start webcam
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Inference
    results = model(frame)
    annotated = results.render()[0]

    # Show output
    cv2.imshow('RotSense - Live Detection', annotated)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\anora/.cache\torch\hub\master.zip
# YOLOv5  2025-7-8 Python-3.10.18 torch-2.7.1+cpu CPU
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.cache\torch\hub\ultralytics_yolov5_master\hubconf.py:70, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      69 try:
# ---> 70     model = DetectMultiBackend(path, device=device, fuse=autoshape)  # detection model
#      71     if autoshape:
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:489, in DetectMultiBackend.__init__(self, weights, device, dnn, data, fp16, fuse)
#     488 if pt:  # PyTorch
# --> 489     model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)
#     490     stride = max(int(model.stride.max()), 32)  # model stride
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\experimental.py:99, in attempt_load(weights, device, inplace, fuse)
#      98 for w in weights if isinstance(weights, list) else [weights]:
# ---> 99     ckpt = torch_load(attempt_download(w), map_location="cpu")  # load
#     100     ckpt = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#
# File ~\Downloads\anaconda\lib\site-packages\ultralytics\utils\patches.py:119, in torch_load(*args, **kwargs)
#     117     kwargs["weights_only"] = False
# --> 119 return _torch_load(*args, **kwargs)
#
# File ~\Downloads\anaconda\lib\site-packages\torch\serialization.py:1479, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1477     pickle_load_args["encoding"] = "utf-8"
# -> 1479 with _open_file_like(f, "rb") as opened_file:
#    1480     if _is_zipfile(opened_file):
#    1481         # The zipfile reader is going to advance the current file position.
#    1482         # If we want to actually tail call to torch.jit.load, we need to
#    1483         # reset back to the original position.
#
# File ~\Downloads\anaconda\lib\site-packages\torch\serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     758 if _is_path(name_or_buffer):
# --> 759     return _open_file(name_or_buffer, mode)
#     760 else:
#
# File ~\Downloads\anaconda\lib\site-packages\torch\serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'best.pt'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.cache\torch\hub\ultralytics_yolov5_master\hubconf.py:85, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      84     except Exception:
# ---> 85         model = attempt_load(path, device=device, fuse=False)  # arbitrary model
#      86 else:
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\experimental.py:99, in attempt_load(weights, device, inplace, fuse)
#      98 for w in weights if isinstance(weights, list) else [weights]:
# ---> 99     ckpt = torch_load(attempt_download(w), map_location="cpu")  # load
#     100     ckpt = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#
# File ~\Downloads\anaconda\lib\site-packages\ultralytics\utils\patches.py:119, in torch_load(*args, **kwargs)
#     117     kwargs["weights_only"] = False
# --> 119 return _torch_load(*args, **kwargs)
#
# File ~\Downloads\anaconda\lib\site-packages\torch\serialization.py:1479, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1477     pickle_load_args["encoding"] = "utf-8"
# -> 1479 with _open_file_like(f, "rb") as opened_file:
#    1480     if _is_zipfile(opened_file):
#    1481         # The zipfile reader is going to advance the current file position.
#    1482         # If we want to actually tail call to torch.jit.load, we need to
#    1483         # reset back to the original position.
#
# File ~\Downloads\anaconda\lib\site-packages\torch\serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     758 if _is_path(name_or_buffer):
# --> 759     return _open_file(name_or_buffer, mode)
#     760 else:
#
# File ~\Downloads\anaconda\lib\site-packages\torch\serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'best.pt'
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[10], line 5
#       2 import cv2
#       4 # Load trained YOLOv5 model
# ----> 5 model = torch.hub.load('ultralytics/yolov5', 'custom', path='best.pt', force_reload=True)
#       7 # Start webcam
#       8 cap = cv2.VideoCapture(0)
#
# File ~\Downloads\anaconda\lib\site-packages\torch\hub.py:647, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     637 if source == "github":
#     638     repo_or_dir = _get_cache_or_reload(
#     639         repo_or_dir,
#     640         force_reload,
#    (...)
#     644         skip_validation=skip_validation,
#     645     )
# --> 647 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     648 return model
#
# File ~\Downloads\anaconda\lib\site-packages\torch\hub.py:680, in _load_local(hubconf_dir, model, *args, **kwargs)
#     677     hub_module = _import_module(MODULE_HUBCONF, hubconf_path)
#     679     entry = _load_entry_from_hubconf(hub_module, model)
# --> 680     model = entry(*args, **kwargs)
#     682 return model
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\hubconf.py:135, in custom(path, autoshape, _verbose, device)
#     106 def custom(path="path/to/model.pt", autoshape=True, _verbose=True, device=None):
#     107     """
#     108     Loads a custom or local YOLOv5 model from a given path with optional autoshaping and device specification.
#     109
#    (...)
#     133         ```
#     134     """
# --> 135     return _create(path, autoshape=autoshape, verbose=_verbose, device=device)
#
# File ~/.cache\torch\hub\ultralytics_yolov5_master\hubconf.py:103, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#     101 help_url = "https://docs.ultralytics.com/yolov5/tutorials/pytorch_hub_model_loading"
#     102 s = f"{e}. Cache may be out of date, try `force_reload=True` or see {help_url} for help."
# --> 103 raise Exception(s) from e
#
# Exception: [Errno 2] No such file or directory: 'best.pt'. Cache may be out of date, try `force_reload=True` or see https://docs.ultralytics.com/yolov5/tutorials/pytorch_hub_model_loading for help.
